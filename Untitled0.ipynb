# %% [markdown]
# <a href="https://colab.research.google.com/github/lilly2000/varshitha_s/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle


Open In Colab
In [0]:

Write a program to print the triangle

n=int(input("Enter number:"));
for i in range(n+1):
    c=i
    for j in range(1,i+1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4

1 
2 3 
3 4 5 
4 5 6 7 
In [0]:

In [2]:
rows = 4
for i in range(0, rows):
    for j in range(0, i + 1):
        print("*", end=' ')

    print("\r")
* 
* * 
* * * 
* * * * 
In [0]:

In [3]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:5

5 
4 5 
3 4 5 
2 3 4 5 
1 2 3 4 5 
In [0]:


Open In Colab
In [0]:

Write a program to print the triangle

In [0]:

In [1]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=i
    for j in range(1,i+1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4

1 
2 3 
3 4 5 
4 5 6 7 
In [0]:

In [2]:
rows = 4
for i in range(0, rows):
    for j in range(0, i + 1):
        print("*", end=' ')

    print("\r")
* 
* * 
* * * 
* * * * 
In [0]:

In [3]:
n=int(input("Enter number:"));
for i in range(n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:5

5 
4 5 
3 4 5 
2 3 4 5 
1 2 3 4 5 
In [0]:

In [4]:
rows = 5
for i in range(0, rows + 1):
    for j in range(rows - i, 0, -1):
        print(j, end=' ')
    print()
5 4 3 2 1 
4 3 2 1 
3 2 1 
2 1 
1 

In [5]:
n=int(input("Enter number:"));
for i in range(n):
    for j in range(i+1,n+1,1):
        print(j, end=" ")
    print('')
for i in range(2,n+1):
    c=n-i+1
    for j in range(n,n-i,-1):
        print(c, end=" ")
        c=c+1
    print('')
Enter number:4
1 2 3 4 
2 3 4 
34 
3 4 
2 3 4 
1 2 3 4 
In [0]:

Find the length of a string without using len functions

In [0]:

In [6]:
str = input("Enter a string: ")
counter = 0
for s in str:
      counter = counter+1
print("Length of the input string is:", counter)
Enter a string: python
Length of the input string is: 6
Find the no of words and characters in a string

In [0]:

In [7]:
string=input("Enter string:")
char=0
word=1
for i in string:
      char=char+1
      if(i==' '):
            word=word+1
print("Number of words in the string:")
print(word)
print("Number of characters in the string:")
print(char)
Enter string:python20
Number of words in the string:
1
Number of characters in the string:
8
In [0]:

Find the no of occurrences of a word in a string

In [8]:
string = "My College name is Alva's Institute of Engineering and technology"
substring = "is"

count = string.count(substring)

# print count
print("The count is:", count)
The count is: 1
# Out:
#   File "<ipython-input-2-55597d20c982>", line 2
#     Open In Colab
#           ^
# SyntaxError: invalid syntax
